# %%
import os
import re
from collections import Counter, defaultdict

# %%
ROOT_PATH = r"C:\Users\BalasubramanianPG\Videos\Obsidian Vault\3. Interview Prep\Stratascratch"

# %% [markdown]
# # Canonical family normalization

# %%
FAMILY_CANONICAL_MAP = {
    "Aggregation Methods": "Aggregations",
    "Aggregate Functions": "Aggregations",
    "Aggregations": "Aggregations",

    "Boolean Indexing": "Filtering",
    "Filtering Data": "Filtering",

    "Column Manipulation": "Column Operations",
    "DataFrame Operations": "Column Operations",

    "Data Cleaning": "Data Cleaning",
    "Conditional Logic": "Conditional Logic",
}

DIFFICULTY_MAP = {"Easy", "Medium", "Hard", "Advanced"}

# %% [markdown]
# # HELPERS

# %%
def clean_yaml_value(value: str) -> str:
    """
    Normalize YAML scalar values:
    - Strip quotes
    - Remove escaped quotes
    - Trim whitespace
    """
    value = value.strip()
    value = value.strip('"').strip("'")
    value = value.replace('\\"', '').replace("\\'", '')
    return value

# %%
def extract_yaml_front_matter(content: str) -> str | None:
    match = re.match(r'^---\n(.*?)\n---', content, re.DOTALL)
    return match.group(1) if match else None

# %%
def normalize_family(family: str) -> str:
    return FAMILY_CANONICAL_MAP.get(family, family)

# %%
def infer_difficulty_from_path(path: str) -> str:
    for part in path.split(os.sep):
        if part in DIFFICULTY_MAP:
            return part
    return "Unknown"

# %% [markdown]
# # Data Collection

# %%
topic_data = []

for current_root, _, files in os.walk(ROOT_PATH):
    for filename in files:
        if not filename.endswith(".md"):
            continue

        file_path = os.path.join(current_root, filename)

        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()

        yaml_content = extract_yaml_front_matter(content)
        if not yaml_content:
            continue

        family_match = re.search(
            r'^topic_family:\s*(.+)$',
            yaml_content,
            re.MULTILINE
        )

        function_match = re.search(
            r'^topic_functions?:\s*(.+)$',   # supports topic_function & topic_functions
            yaml_content,
            re.MULTILINE
        )

        raw_family = clean_yaml_value(family_match.group(1)) if family_match else "UNKNOWN_FAMILY"
        raw_function = clean_yaml_value(function_match.group(1)) if function_match else "UNKNOWN_FUNCTION"

        family = normalize_family(raw_family)
        function = raw_function

        difficulty = infer_difficulty_from_path(current_root)

        topic_data.append({
            "filename": filename,
            "path": current_root,
            "difficulty": difficulty,
            "family": family,
            "function": function
        })

# %% [markdown]
# ## Analysis

# %%
family_counter = Counter(item["family"] for item in topic_data)
function_counter = Counter(item["function"] for item in topic_data)
difficulty_counter = Counter(item["difficulty"] for item in topic_data)
combo_counter = Counter(
    (item["family"], item["function"], item["difficulty"])
    for item in topic_data
)

# %% [markdown]
# ## Output

# %%
print("\nTopic Family Counts:")
print("-" * 30)
for family, count in family_counter.most_common():
    print(f'{family}: {count}')

print("\nTopic Function Counts:")
print("-" * 30)
for func, count in function_counter.most_common():
    print(f'{func}: {count}')

print("\nDifficulty Distribution:")
print("-" * 30)
for diff, count in difficulty_counter.items():
    print(f'{diff}: {count}')

print("\nTotal Files Processed:", len(topic_data))
print("Unique Topic Families:", len(family_counter))
print("Unique Topic Functions:", len(function_counter))

print("\nFamily → Function → Difficulty Breakdown:")
print("-" * 45)
for (family, func, diff), count in combo_counter.most_common():
    print(f'{family} → {func} → {diff}: {count}')
# Out:
# Topic Family Counts:
# ------------------------------
# - "Aggregate Functions: 268
# - "Aggregations: 64
# - "Aggregation Methods: 62
# - "Boolean Indexing: 35
# - "Data Cleaning: 15
# - "Column Manipulation: 13
# - "Conditional Logic: 4
# UNKNOWN_FAMILY: 3
# - "Data Retrieval Basics: 2
# - "Filtering Data: 2
# - "DataFrame Operations: 2
# - "Combining: 1
# - "Distinct Counts: 1
# - "Array Operation: 1
# - "DataFrame Functions: 1
# - "DataFrame Creation: 1
#
# Topic Function Counts:
# ------------------------------
# - "agg(): 114
# - "alias(): 74
# - "arrange(): 57
# - "apply(): 31
# - "col(): 26
# - "avg(): 18
# - "case when: 17
# - "count(): 16
# - "cast(): 9
# - "as.Date(): 8
# - "append(): 8
# - "abs(): 7
# - "anti_join(): 7
# - "astype(): 6
# - "as.integer(): 5
# - "between(): 5
# - "coalesce(): 4
# - "and: 4
# - "assign(): 4
# - "distinct(): 4
# - "bind_rows(): 3
# - "ave(): 3
# - "as.character(): 3
# UNKNOWN_FUNCTION: 3
# - "acos(): 2
# - "array_length(): 2
# - "group_by(): 2
# - "as.POSIXct(): 2
# - "contains(): 2
# - "aggregate(): 2
# - "add_prefix(): 2
# - "filter(): 2
# - "as.numeric(): 2
# - "dense_rank(): 2
# - "max(): 2
# - "at: 1
# - "groupby(): 1
# - "is.na(): 1
# - "convert(): 1
# - "dt(): 1
# - "date_format(): 1
# - ".agg(): 1
# - "all(): 1
# - "c_across(): 1
# - "c(): 1
# - "across(): 1
# - "data.frame(): 1
# - "asc(): 1
# - "case_when(): 1
# - "collect(): 1
# - "%>%: 1
# - "drop_duplicates(): 1
#
# Difficulty Distribution:
# ------------------------------
# Easy: 126
# Hard: 105
# Medium: 244
#
# Total Files Processed: 475
# Unique Topic Families: 16
# Unique Topic Functions: 52
#
# Family → Function → Difficulty Breakdown:
# ---------------------------------------------
# - "Aggregate Functions → - "agg() → Medium: 39
# - "Aggregate Functions → - "alias() → Medium: 31
# - "Aggregate Functions → - "agg() → Hard: 23
# - "Aggregate Functions → - "arrange() → Medium: 20
# - "Aggregate Functions → - "agg() → Easy: 19
# - "Aggregation Methods → - "agg() → Medium: 12
# - "Aggregation Methods → - "alias() → Medium: 10
# - "Aggregate Functions → - "alias() → Easy: 7
# - "Aggregations → - "agg() → Medium: 7
# - "Aggregate Functions → - "avg() → Medium: 7
# - "Aggregate Functions → - "avg() → Easy: 6
# - "Boolean Indexing → - "col() → Easy: 6
# - "Aggregations → - "arrange() → Hard: 6
# - "Aggregate Functions → - "case when → Medium: 6
# - "Aggregate Functions → - "count() → Medium: 6
# - "Aggregation Methods → - "agg() → Easy: 5
# - "Aggregation Methods → - "alias() → Easy: 5
# - "Aggregation Methods → - "agg() → Hard: 5
# - "Aggregate Functions → - "arrange() → Hard: 5
# - "Aggregate Functions → - "alias() → Hard: 5
# - "Aggregate Functions → - "col() → Medium: 5
# - "Aggregations → - "alias() → Medium: 5
# - "Aggregate Functions → - "cast() → Medium: 5
# - "Aggregate Functions → - "arrange() → Easy: 4
# - "Aggregations → - "arrange() → Easy: 4
# - "Aggregations → - "agg() → Hard: 4
# - "Aggregate Functions → - "avg() → Hard: 4
# - "Boolean Indexing → - "col() → Medium: 4
# - "Aggregate Functions → - "apply() → Medium: 4
# - "Aggregation Methods → - "arrange() → Medium: 4
# - "Aggregate Functions → - "apply() → Easy: 3
# - "Aggregations → - "apply() → Easy: 3
# - "Aggregate Functions → - "between() → Easy: 3
# - "Aggregate Functions → - "count() → Easy: 3
# - "Aggregation Methods → - "alias() → Hard: 3
# - "Aggregate Functions → - "apply() → Hard: 3
# - "Aggregate Functions → - "as.Date() → Hard: 3
# - "Aggregate Functions → - "append() → Hard: 3
# - "Aggregate Functions → - "case when → Hard: 3
# - "Aggregation Methods → - "col() → Medium: 3
# - "Boolean Indexing → - "apply() → Medium: 3
# - "Aggregate Functions → - "coalesce() → Medium: 3
# - "Aggregate Functions → - "col() → Easy: 2
# - "Aggregate Functions → - "as.integer() → Easy: 2
# - "Aggregation Methods → - "apply() → Easy: 2
# - "Aggregate Functions → - "as.Date() → Easy: 2
# - "Aggregate Functions → - "and → Easy: 2
# - "Boolean Indexing → - "anti_join() → Easy: 2
# - "Aggregations → - "ave() → Easy: 2
# - "Aggregate Functions → - "case when → Easy: 2
# - "Column Manipulation → - "arrange() → Easy: 2
# - "Column Manipulation → - "assign() → Easy: 2
# - "Aggregate Functions → - "append() → Easy: 2
# - "Aggregations → - "bind_rows() → Hard: 2
# - "Aggregate Functions → - "as.integer() → Hard: 2
# - "Aggregation Methods → - "apply() → Hard: 2
# - "Aggregations → - "apply() → Hard: 2
# - "Aggregate Functions → - "abs() → Hard: 2
# - "Boolean Indexing → - "apply() → Hard: 2
# - "Aggregations → - "alias() → Hard: 2
# - "Boolean Indexing → - "anti_join() → Hard: 2
# - "Boolean Indexing → - "distinct() → Medium: 2
# - "Data Cleaning → - "arrange() → Medium: 2
# - "Data Cleaning → - "col() → Medium: 2
# - "Data Cleaning → - "apply() → Medium: 2
# - "Aggregations → - "col() → Medium: 2
# - "Aggregate Functions → - "as.Date() → Medium: 2
# - "Aggregations → - "arrange() → Medium: 2
# - "Boolean Indexing → - "arrange() → Medium: 2
# - "Aggregations → - "count() → Medium: 2
# - "Aggregate Functions → - "abs() → Medium: 2
# - "Column Manipulation → - "case when → Medium: 2
# - "Aggregation Methods → - "dense_rank() → Medium: 2
# - "Boolean Indexing → - "max() → Medium: 2
# - "Aggregations → - "bind_rows() → Easy: 1
# - "Data Retrieval Basics → - "arrange() → Easy: 1
# - "Aggregate Functions → - "acos() → Easy: 1
# - "Aggregations → - "array_length() → Easy: 1
# - "Aggregations → - "case when → Easy: 1
# - "Aggregate Functions → - "abs() → Easy: 1
# - "Aggregation Methods → - "coalesce() → Easy: 1
# - "Column Manipulation → - "apply() → Easy: 1
# - "Combining → - "at → Easy: 1
# - "Filtering Data → - "alias() → Easy: 1
# - "Distinct Counts → - "alias() → Easy: 1
# - "Boolean Indexing → - "arrange() → Easy: 1
# - "Aggregation Methods → - "group_by() → Easy: 1
# - "Aggregations → - "groupby() → Easy: 1
# - "Boolean Indexing → - "count() → Easy: 1
# - "DataFrame Operations → - "group_by() → Easy: 1
# - "Aggregate Functions → - "cast() → Easy: 1
# - "Data Cleaning → - "cast() → Easy: 1
# - "Data Cleaning → - "is.na() → Easy: 1
# - "Conditional Logic → - "count() → Easy: 1
# - "Aggregation Methods → - "convert() → Easy: 1
# - "Aggregate Functions → - "dt() → Easy: 1
# - "Aggregations → - "date_format() → Easy: 1
# - "Aggregation Methods → - "cast() → Easy: 1
# - "Boolean Indexing → - "as.POSIXct() → Easy: 1
# - "Data Cleaning → - "astype() → Easy: 1
# - "Boolean Indexing → - "as.character() → Easy: 1
# - "Data Cleaning → - "apply() → Easy: 1
# - "Data Cleaning → - "col() → Easy: 1
# - "Aggregations → - "contains() → Easy: 1
# - "Aggregate Functions → - "as.character() → Easy: 1
# - "Aggregations → - "astype() → Easy: 1
# - "Aggregate Functions → - "astype() → Easy: 1
# - "Boolean Indexing → - "apply() → Easy: 1
# - "Aggregation Methods → - "append() → Easy: 1
# UNKNOWN_FAMILY → UNKNOWN_FUNCTION → Easy: 1
# - "Aggregate Functions → - "col() → Hard: 1
# - "Data Retrieval Basics → - "arrange() → Hard: 1
# - "Aggregate Functions → - "acos() → Hard: 1
# - "Aggregations → - "array_length() → Hard: 1
# - "Aggregations → - "case when → Hard: 1
# - "Aggregate Functions → - "between() → Hard: 1
# - "Column Manipulation → - "apply() → Hard: 1
# - "Aggregate Functions → - "and → Hard: 1
# - "Aggregate Functions → - ".agg() → Hard: 1
# - "Array Operation → - "all() → Hard: 1
# - "Aggregate Functions → - "c_across() → Hard: 1
# - "Aggregations → - "count() → Hard: 1
# - "Aggregation Methods → - "aggregate() → Hard: 1
# - "Aggregations → - "assign() → Hard: 1
# - "Aggregate Functions → - "add_prefix() → Hard: 1
# - "Column Manipulation → - "arrange() → Hard: 1
# - "Aggregations → - "contains() → Hard: 1
# - "Aggregate Functions → - "count() → Hard: 1
# - "Aggregate Functions → - "astype() → Hard: 1
# - "Aggregation Methods → - "append() → Hard: 1
# - "Aggregations → - "ave() → Hard: 1
# UNKNOWN_FAMILY → UNKNOWN_FUNCTION → Hard: 1
# - "Boolean Indexing → - "astype() → Medium: 1
# - "Column Manipulation → - "c() → Medium: 1
# - "Aggregations → - "distinct() → Medium: 1
# - "Data Cleaning → - "filter() → Medium: 1
# - "Aggregate Functions → - "as.numeric() → Medium: 1
# - "Aggregate Functions → - "across() → Medium: 1
# - "Data Cleaning → - "data.frame() → Medium: 1
# - "Boolean Indexing → - "asc() → Medium: 1
# - "Aggregate Functions → - "case_when() → Medium: 1
# - "Conditional Logic → - "arrange() → Medium: 1
# - "Boolean Indexing → - "alias() → Medium: 1
# - "Aggregate Functions → - "collect() → Medium: 1
# - "Aggregations → - "as.Date() → Medium: 1
# - "Aggregate Functions → - "and → Medium: 1
# - "Column Manipulation → - "alias() → Medium: 1
# - "Filtering Data → - "alias() → Medium: 1
# - "DataFrame Functions → - "alias() → Medium: 1
# - "Aggregation Methods → - "case when → Medium: 1
# - "Aggregate Functions → - "assign() → Medium: 1
# - "Aggregations → - "between() → Medium: 1
# - "Aggregate Functions → - "anti_join() → Medium: 1
# - "Boolean Indexing → - "abs() → Medium: 1
# - "DataFrame Operations → - "distinct() → Medium: 1
# - "Conditional Logic → - "filter() → Medium: 1
# - "Column Manipulation → - "anti_join() → Medium: 1
# - "Aggregate Functions → - "append() → Medium: 1
# - "Aggregations → - "as.integer() → Medium: 1
# - "Aggregate Functions → - "astype() → Medium: 1
# - "Aggregate Functions → - "aggregate() → Medium: 1
# - "Conditional Logic → - "case when → Medium: 1
# - "Aggregate Functions → - "add_prefix() → Medium: 1
# - "Aggregations → - "cast() → Medium: 1
# - "Aggregations → - "abs() → Medium: 1
# - "Boolean Indexing → - "as.POSIXct() → Medium: 1
# - "Aggregations → - "as.numeric() → Medium: 1
# - "DataFrame Creation → - "arrange() → Medium: 1
# - "Column Manipulation → - "apply() → Medium: 1
# - "Data Cleaning → - "as.character() → Medium: 1
# - "Aggregations → - "avg() → Medium: 1
# - "Aggregation Methods → - "count() → Medium: 1
# - "Data Cleaning → - "anti_join() → Medium: 1
# - "Aggregate Functions → - "%>% → Medium: 1
# - "Aggregate Functions → - "drop_duplicates() → Medium: 1
# UNKNOWN_FAMILY → UNKNOWN_FUNCTION → Medium: 1
